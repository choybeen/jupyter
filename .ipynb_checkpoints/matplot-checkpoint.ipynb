# %%
import numpy as np
import pandas as pd
from numpy.random import rand
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N=100
t = np.linspace(0,np.pi*5, 100)
x = np.cos(t)
plt.figure()
plt.plot(x)
plt.title("cos")
plt.Text(0.5,1,"cos")
# Out:
# Text(0.5, 1, 'cos')

# %%
y = np.cos(t*2)
plt.plot(t,x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x23547342848>,
#  <matplotlib.lines.Line2D at 0x23547328608>]

# %%
plt.plot(t,x,'r-o',x,y,'b-+')
plt.legend(['sin(x)','sin(5x)'])

# %%
e = rand(N)*0.5
e
x += e
colors = rand(N)
area = rand(N)*100
plt.scatter(t,x, s=area, c=colors)
plt.colorbar()

# %%
e1 = rand(N)
e2 = rand(N)*2
e3 = rand(N)*10
e4 = rand(N)*100
corrmatrix = np.corrcoef([e1,e2,e3,e4])
plt.imshow(corrmatrix,cmap='GnBu')
plt.colorbar()
plt.savefig('plot.jpg')
# %pwd
# Out:
# 'D:\\jupyterNote\\NumpyPanda'

# %%
plt.subplot(2,1,1)
plt.plot(t,x)
plt.subplot(2,1,2)
plt.plot(t,y)

# %%
plt.subplot(1,2,1)
plt.plot(t,x)
plt.subplot(1,2,2)
plt.plot(t,y)

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(t,x)
plt.subplot(1,2,2)
plt.plot(t,y)

# %%
from numpy.random import randint
data = randint(1000,size=(10,1000))
x=np.sum(data,axis=0)
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.hist(x,color='r')
plt.subplot(1,2,2)
plt.hist(x,cumulative=True,color='g')
# Out:
# (array([   3.,   20.,   67.,  200.,  433.,  687.,  871.,  965.,  994.,
#         1000.]),
#  array([1667. , 2295.2, 2923.4, 3551.6, 4179.8, 4808. , 5436.2, 6064.4,
#         6692.6, 7320.8, 7949. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist([x,x,x])
# Out:
# (array([[  7.,  22.,  66., 170., 208., 234., 185.,  73.,  28.,   7.],
#         [  7.,  22.,  66., 170., 208., 234., 185.,  73.,  28.,   7.],
#         [  7.,  22.,  66., 170., 208., 234., 185.,  73.,  28.,   7.]]),
#  array([2155. , 2714.4, 3273.8, 3833.2, 4392.6, 4952. , 5511.4, 6070.8,
#         6630.2, 7189.6, 7749. ]),
#  <a list of 3 BarContainer objects>)

# %%
plt.plot(np.cos(t),label='cos')
plt.plot(np.sin(t),label='sin')
plt.legend()

# %%
plt.plot(t, np.cos(t),label='cos')
plt.plot(t, np.sin(t),label='sin')
plt.legend()
plt.title("con/sin")
# Out:
# Text(0.5, 1.0, 'con/sin')

# %%
arr_1 = np.random.randint(1,7,5000)
arr_2 = np.random.randint(1,7,5000)
arr_3 = arr_1 + arr_2 #np.random.randint(1,7,5000)
plt.hist(arr_3,bins=11, density=True, stacked=True)
# Out:
# (array([0.03102, 0.05984, 0.09658, 0.11594, 0.15862, 0.19008, 0.1485 ,
#         0.11396, 0.0902 , 0.06512, 0.03014]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2
plt.plot(x_1,y_1, label='x/x2')
plt.plot(y_1,x_1, label='x2/x')
plt.title('Days squared chart')
plt.xlabel('days')
plt.ylabel('days squared')
# Out:
# Text(0, 0.5, 'days squared')

# %%
N1=10
t_2 = np.linspace(0,np.pi*5, N1)
x_2 = rand(N1)*0.5
x_var = rand(N1)*0.01
colors = rand(N1)
plt.bar(t_2,x_2,yerr=x_var)
# Out:
# <BarContainer object of 10 artists>

# %%
N1=10
t_2 = np.linspace(0,np.pi*5, N1)
x_2 = rand(N1)*0.5
x_3 = rand(N1)*0.3
x_var = rand(N1)*0.01
colors = rand(N1)
spc = np.arange(N1)
plt.bar(spc,x_2,width=0.45,yerr=x_var)
plt.bar(spc+0.5,x_3,width=0.45,yerr=x_var)
# Out:
# <BarContainer object of 10 artists>

# %%
N1=10
t_2 = np.linspace(0,np.pi*5, N1)
x_2 = rand(N1)*0.5
x_3 = 0.5-x_2 #rand(N1)*0.5
x_var = rand(N1)*0.01
colors = rand(N1)
spc = np.arange(N1)
plt.bar(spc,x_2,width=0.45,label='male',bottom=x_3)
plt.bar(spc,x_3,width=0.45,label='female')
# Out:
# <BarContainer object of 10 artists>

# %%
N1=7
t_2 = np.linspace(0,np.pi*5, N1)
x_2 = rand(N1)*0.5
x_3 = 0.5-x_2 #rand(N1)*0.5
x_var = rand(N1)*0.01
colors = rand(N1)
wedges, texts,autotexts = plt.pie(x_2,autopct='%1.0f%%')
types = ['a','b','c','c','e','f','g']
plt.legend(wedges,types,loc='right',bbox_to_anchor=(1,0,0.5,1))

# %%
gd = pd.read_csv('goog.csv')
gd.head(5)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-12-31  1330.109985  1338.000000  1329.084961  1337.020020
# 1  2020-01-02  1341.550049  1368.140015  1341.550049  1367.369995
# 2  2020-01-03  1347.859985  1372.500000  1345.543945  1360.660034
# 3  2020-01-06  1350.000000  1396.500000  1350.000000  1394.209961
# 4  2020-01-07  1397.939941  1402.989990  1390.380005  1393.339966
#
#      Adj Close   Volume
# 0  1337.020020   961800
# 1  1367.369995  1406600
# 2  1360.660034  1186400
# 3  1394.209961  1732300
# 4  1393.339966  1502700

# %%
gd_np = gd.to_numpy()
gd_np
# Out:
# array([['2019-12-31', 1330.109985, 1338.0, ..., 1337.02002, 1337.02002,
#         961800],
#        ['2020-01-02', 1341.550049, 1368.140015, ..., 1367.369995,
#         1367.369995, 1406600],
#        ['2020-01-03', 1347.859985, 1372.5, ..., 1360.660034, 1360.660034,
#         1186400],
#        ...,
#        ['2020-12-29', 1787.790039, 1792.439941, ..., 1758.719971,
#         1758.719971, 1299400],
#        ['2020-12-30', 1762.0100100000002, 1765.094971, ..., 1739.52002,
#         1739.52002, 1305300],
#        ['2020-12-31', 1735.4200440000002, 1758.930054, ..., 1751.880005,
#         1751.880005, 975939]], dtype=object)

# %%
gd_cp = gd_np[:,4]
gd_cp[0:10]
plt.plot(gd_cp,label='price')
plt.xlabel('close price')
# Out:
# Text(0.5, 0, 'close price')

# %%
from mpl_toolkits import mplot3d
fig9 = plt.figure(figsize=(8,5),dpi=100)
axis = fig9.add_axes([0.1,0.1,0.9,0.9],projection='3d')

N2=40
t_2 = np.linspace(0,np.pi*5, N2)
x_2 = rand(N2)*0.5
x_3 = rand(N2)*0.5
axis.scatter3D(t_2,x_2,x_3,c=x_3,cmap='Blues')

# %%
def get_z(x,y):
    return np.sin(np.sqrt(x**2+y**2))

N2=50
x_2 = np.linspace(-16,16,N2)
x_3 = np.linspace(-16,16,N2)
x_4,y_4 = np.meshgrid(x_2,x_3)
z_4 = get_z(x_4,y_4)
fig10 = plt.figure(figsize=(8,5),dpi=100)
axis10 = fig10.add_axes([0.1,0.1,0.9,0.9],projection='3d')
axis10.contour3D(x_4,y_4,z_4, N2, cmap='Blues')

# %%
fig10 = plt.figure(figsize=(8,5),dpi=100)
axis10 = fig10.add_axes([0.1,0.1,0.9,0.9],projection='3d')
axis10.plot_wireframe(x_4,y_4,z_4, cmap='Blues')

# %%
fig10 = plt.figure(figsize=(8,5),dpi=100)
axis10 = fig10.add_axes([0.1,0.1,0.9,0.9],projection='3d')
axis10.plot_surface(x_4,y_4,z_4,rstride=1,cstride=1,cmap='Blues')
