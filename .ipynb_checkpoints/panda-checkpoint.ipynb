# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
df.shape
#df.info
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0   European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1  Pound sterling  ...                         NaN                    NaN
# 2             NaN  ...  Neither easy nor difficult  Appropriate in length
# 3    Albanian lek  ...                         NaN                    NaN
# 4             NaN  ...                        Easy              Too short
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 3    No  Computer science, computer engineering, or sof...
# 4    No  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4   Django;Ruby on Rails         Ruby on Rails
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 0   Just as welcome now as I felt last year        50.0        36           27
# 1  Somewhat more welcome now than last year         NaN         7            4
# 2  Somewhat more welcome now than last year         NaN         4          NaN
# 3  Somewhat less welcome now than last year        40.0         7            4
# 4   Just as welcome now as I felt last year         NaN        15            8
#
# [5 rows x 61 columns]

# %%
df_schema = pd.read_csv('survey_results_schema.csv')
df_schema.shape, df_schema.tail()
df_schema.head()
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
df[['Hobbyist','Country']][0:5]
# Out:
#   Hobbyist             Country
# 0      Yes             Germany
# 1       No      United Kingdom
# 2      Yes  Russian Federation
# 3      Yes             Albania
# 4      Yes       United States

# %%
df[['Hobbyist','Country']].value_counts()
# Out:
# Hobbyist  Country
# Yes       United States          9718
#           India                  6645
#           Germany                3249
#           United Kingdom         3029
# No        United States          2751
#                                  ...
#           Solomon Islands           1
#           Gambia                    1
#           Yemen                     1
#           Trinidad and Tobago       1
#           Timor-Leste               1
# Length: 333, dtype: int64

# %%
df.Country[0:2]
# Out:
# 0           Germany
# 1    United Kingdom
# Name: Country, dtype: object

# %%
df.iloc[[0,2,4],[0,1,2,3,4,5]]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 2           3                        I code primarily as a hobby      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq
# 0   NaN         13  Monthly
# 2   NaN         15      NaN
# 4  31.0         16      NaN

# %%
df.loc[[0,2,4], ['Hobbyist', 'Age','Country']]
# Out:
#   Hobbyist   Age             Country
# 0      Yes   NaN             Germany
# 2      Yes   NaN  Russian Federation
# 4      Yes  31.0       United States

# %%
df.loc[0:4, ['Hobbyist', 'Age','Country']]
# Out:
#   Hobbyist   Age             Country
# 0      Yes   NaN             Germany
# 1       No   NaN      United Kingdom
# 2      Yes   NaN  Russian Federation
# 3      Yes  25.0             Albania
# 4      Yes  31.0       United States

# %%
df.loc[0:4, 'Hobbyist':'Country']
# Out:
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
# 4      Yes  31.0         16      NaN        NaN            NaN
#
#               Country
# 0             Germany
# 1      United Kingdom
# 2  Russian Federation
# 3             Albania
# 4       United States

# %%
filt = (df['Country']=='Germany') 
df[filt].head()
filt = (df['Country']=='Germany') & (df['Hobbyist']=='Yes') 
df[filt].head()
# Out:
#     Respondent                              MainBranch Hobbyist   Age  \
# 0            1          I am a developer by profession      Yes   NaN
# 22          23          I am a developer by profession      Yes  27.0
# 23          24          I am a developer by profession      Yes  45.0
# 33          34          I am a developer by profession      Yes  29.0
# 59          60  I am a student who is learning to code      Yes   NaN
#
#    Age1stCode CompFreq  CompTotal  ConvertedComp  Country   CurrencyDesc  ...  \
# 0          13  Monthly        NaN            NaN  Germany  European Euro  ...
# 22         14      NaN        NaN            NaN  Germany  European Euro  ...
# 23         14   Yearly    85000.0        91883.0  Germany  European Euro  ...
# 33         15      NaN        NaN            NaN  Germany            NaN  ...
# 59         14      NaN        NaN            NaN  Germany            NaN  ...
#
#                     SurveyEase           SurveyLength Trans  \
# 0   Neither easy nor difficult  Appropriate in length    No
# 22                        Easy  Appropriate in length    No
# 23                        Easy  Appropriate in length    No
# 33                        Easy  Appropriate in length    No
# 59                        Easy  Appropriate in length    No
#
#                                        UndergradMajor  \
# 0   Computer science, computer engineering, or sof...
# 22  Another engineering discipline (such as civil,...
# 23  Another engineering discipline (such as civil,...
# 33  Computer science, computer engineering, or sof...
# 59                                                NaN
#
#              WebframeDesireNextYear    WebframeWorkedWith  \
# 0                      ASP.NET Core  ASP.NET;ASP.NET Core
# 22                              NaN                   NaN
# 23                              NaN                   NaN
# 33  Angular;Express;React.js;Spring       Angular;Express
# 59                           Django                   NaN
#
#                                WelcomeChange WorkWeekHrs YearsCode  \
# 0    Just as welcome now as I felt last year        50.0        36
# 22  Somewhat less welcome now than last year        40.0         8
# 23   Just as welcome now as I felt last year        42.0        30
# 33  Somewhat more welcome now than last year         NaN        10
# 59   Just as welcome now as I felt last year         NaN         2
#
#    YearsCodePro
# 0            27
# 22            3
# 23           20
# 33          NaN
# 59          NaN
#
# [5 rows x 61 columns]

# %%
df.loc[filt,['Age','Hobbyist']].head()
# Out:
#      Age Hobbyist
# 0    NaN      Yes
# 22  27.0      Yes
# 23  45.0      Yes
# 33  29.0      Yes
# 59   NaN      Yes

# %%
df.loc[~filt,['Age','Hobbyist']].head()
# Out:
#     Age Hobbyist
# 1   NaN       No
# 2   NaN      Yes
# 3  25.0      Yes
# 4  31.0      Yes
# 5   NaN       No

# %%
df.columns = [x.upper() for x in df.columns]
df.loc[10:12][0:4]
# Out:
#     RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 10          11                     I am a developer by profession    Great
# 11          12                     I am a developer by profession       No
# 12          13  I am not primarily a developer, but I write co...      Yes
#
#      AGE AGE1STCODE COMPFREQ  COMPTOTAL  CONVERTEDCOMP         COUNTRY  \
# 10  23.0         13   Yearly    31000.0        40070.0  United Kingdom
# 11  49.0         42  Monthly     1100.0        14268.0           Spain
# 12  53.0         14  Monthly     3000.0        38916.0     Netherlands
#
#       CURRENCYDESC  ...                  SURVEYEASE           SURVEYLENGTH  \
# 10  Pound sterling  ...                        Easy  Appropriate in length
# 11   European Euro  ...                        Easy  Appropriate in length
# 12   European Euro  ...  Neither easy nor difficult               Too long
#
#    TRANS                                     UNDERGRADMAJOR  \
# 10    No  Computer science, computer engineering, or sof...
# 11    No                          Mathematics or statistics
# 12    No                                                NaN
#
#      WEBFRAMEDESIRENEXTYEAR                  WEBFRAMEWORKEDWITH  \
# 10  Angular;Django;React.js  Angular;Angular.js;Django;React.js
# 11           ASP.NET;jQuery                      ASP.NET;jQuery
# 12                      NaN                                 NaN
#
#                               WELCOMECHANGE WORKWEEKHRS YEARSCODE YEARSCODEPRO
# 10  Just as welcome now as I felt last year        40.0        10            2
# 11  Just as welcome now as I felt last year        40.0         7            7
# 12    A lot less welcome now than last year        36.0        35           20
#
# [3 rows x 61 columns]

# %%
df.loc[10,'HOBBYIST']
df.loc[10,'HOBBYIST'] = "Great"
df.loc[10,'HOBBYIST']
# Out:
# 'Great'

# %%
df[10,'HOBBYIST'] = "Yes" # would not work
df.loc[10,'HOBBYIST']
# Out:
# 'Great'

# %%
df.loc[10:15, 'MAINBRANCH'].apply(len)
# Out:
# 10    30
# 11    30
# 12    77
# 13    30
# 14    38
# 15    30
# Name: MAINBRANCH, dtype: int64

# %%
def updateAges(ages):
    ages = ages * 1.1
df.loc[10:20,'AGE'].apply(updateAges)    
df.loc[10:20,'AGE']
# Out:
# 10    23.0
# 11    49.0
# 12    53.0
# 13    27.0
# 14     NaN
# 15    45.0
# 16    25.0
# 17    32.0
# 18    24.0
# 19    40.0
# 20    23.0
# Name: AGE, dtype: float64

# %%
df.loc[10:20,'AGE']
df.loc[10:20,'AGE'].apply(lambda x : x*1.1)
# Out:
# 10    25.3
# 11    53.9
# 12    58.3
# 13    29.7
# 14     NaN
# 15    49.5
# 16    27.5
# 17    35.2
# 18    26.4
# 19    44.0
# 20    25.3
# Name: AGE, dtype: float64

# %%
df.loc[10:20][1:10].apply(len)
# Out:
# RESPONDENT        9
# MAINBRANCH        9
# HOBBYIST          9
# AGE               9
# AGE1STCODE        9
#                  ..
# WELCOMECHANGE     9
# WORKWEEKHRS       9
# YEARSCODE         9
# YEARSCODEPRO      9
# (10, HOBBYIST)    9
# Length: 62, dtype: int64

# %%
df['HOBBYIST'].map({'Yes':True, 'No':False}),df['HOBBYIST']
# Out:
# (0         True
#  1        False
#  2         True
#  3         True
#  4         True
#           ...
#  64456     True
#  64457     True
#  64458     True
#  64459     True
#  64460     True
#  Name: HOBBYIST, Length: 64461, dtype: object,
#  0        Yes
#  1         No
#  2        Yes
#  3        Yes
#  4        Yes
#          ...
#  64456    Yes
#  64457    Yes
#  64458    Yes
#  64459    Yes
#  64460    Yes
#  Name: HOBBYIST, Length: 64461, dtype: object)

# %%
df['HOBBYIST'].replace({'Yes':True, 'No':False}),df['HOBBYIST']
# Out:
# (0         True
#  1        False
#  2         True
#  3         True
#  4         True
#           ...
#  64456     True
#  64457     True
#  64458     True
#  64459     True
#  64460     True
#  Name: HOBBYIST, Length: 64461, dtype: object,
#  0        Yes
#  1         No
#  2        Yes
#  3        Yes
#  4        Yes
#          ...
#  64456    Yes
#  64457    Yes
#  64458    Yes
#  64459    Yes
#  64460    Yes
#  Name: HOBBYIST, Length: 64461, dtype: object)

# %%
df.loc[100:105].sort_values(by=['AGE'],ascending=True)
# Out:
#      RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 101         103  I am not primarily a developer, but I write co...      Yes
# 104         106                     I am a developer by profession      Yes
# 103         105                     I am a developer by profession      Yes
# 105         107                     I am a developer by profession      Yes
# 100         102                     I am a developer by profession      Yes
# 102         104  I am not primarily a developer, but I write co...      Yes
#
#       AGE AGE1STCODE COMPFREQ  COMPTOTAL  CONVERTEDCOMP  \
# 101  20.0         15      NaN        NaN            NaN
# 104  24.0         12  Monthly     3550.0        46044.0
# 103  28.0         16   Yearly    40000.0        40000.0
# 105  29.0         13   Yearly   148000.0       148000.0
# 100  37.0         10      NaN        NaN            NaN
# 102  38.0         16  Monthly        NaN            NaN
#
#                     COUNTRY                             CURRENCYDESC  ...  \
# 101           United States                                      NaN  ...
# 104                 Germany                            European Euro  ...
# 103           United States                     United States dollar  ...
# 105           United States                     United States dollar  ...
# 100          United Kingdom                           Pound sterling  ...
# 102  Bosnia and Herzegovina  Bosnia and Herzegovina convertible mark  ...
#
#               SURVEYLENGTH TRANS  \
# 101  Appropriate in length    No
# 104  Appropriate in length    No
# 103  Appropriate in length    No
# 105  Appropriate in length    No
# 100               Too long    No
# 102               Too long    No
#
#                                         UNDERGRADMAJOR  \
# 101  Computer science, computer engineering, or sof...
# 104  Computer science, computer engineering, or sof...
# 103  Computer science, computer engineering, or sof...
# 105  A humanities discipline (such as literature, h...
# 100  Computer science, computer engineering, or sof...
# 102  Information systems, information technology, o...
#
#            WEBFRAMEDESIRENEXTYEAR                          WEBFRAMEWORKEDWITH  \
# 101                  Flask;jQuery                                Flask;jQuery
# 104          ASP.NET;ASP.NET Core                        ASP.NET;ASP.NET Core
# 103   Angular;ASP.NET Core;Vue.js  Angular;ASP.NET;ASP.NET Core;jQuery;Vue.js
# 105        Gatsby;React.js;Vue.js                             Gatsby;React.js
# 100                           NaN                                         NaN
# 102  Angular;ASP.NET Core;Laravel                 ASP.NET Core;jQuery;Laravel
#
#                                 WELCOMECHANGE WORKWEEKHRS YEARSCODE  \
# 101   Just as welcome now as I felt last year         NaN         3
# 104   Just as welcome now as I felt last year        40.0        12
# 103   Just as welcome now as I felt last year        40.0         6
# 105  Somewhat more welcome now than last year        45.0         5
# 100   Just as welcome now as I felt last year        38.0        25
# 102   Just as welcome now as I felt last year         NaN        10
#
#          YEARSCODEPRO (10, HOBBYIST)
# 101               NaN            Yes
# 104                 3            Yes
# 103  Less than 1 year            Yes
# 105                 5            Yes
# 100                12            Yes
# 102                 8            Yes
#
# [6 rows x 62 columns]

# %%
df.loc[10:20].sort_values(by=['AGE','CONVERTEDCOMP'],ascending=[True,False])
# Out:
#     RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 10          11                     I am a developer by profession    Great
# 20          21             I am a student who is learning to code      Yes
# 18          19                     I am a developer by profession       No
# 16          17                     I am a developer by profession      Yes
# 13          14                     I am a developer by profession      Yes
# 17          18                     I am a developer by profession      Yes
# 19          20                     I am a developer by profession      Yes
# 15          16                     I am a developer by profession      Yes
# 11          12                     I am a developer by profession       No
# 12          13  I am not primarily a developer, but I write co...      Yes
# 14          15             I am a student who is learning to code      Yes
#
#      AGE AGE1STCODE COMPFREQ  COMPTOTAL  CONVERTEDCOMP         COUNTRY  \
# 10  23.0         13   Yearly    31000.0        40070.0  United Kingdom
# 20  23.0         16      NaN        NaN            NaN         Belgium
# 18  24.0         15   Yearly    83400.0        83400.0   United States
# 16  25.0         14   Yearly    79000.0        79000.0   United States
# 13  27.0         13   Yearly    66000.0        66000.0   United States
# 17  32.0         12  Monthly   105000.0      1260000.0   United States
# 19  40.0         18      NaN        NaN            NaN           Spain
# 15  45.0          8  Monthly     7000.0       108576.0  United Kingdom
# 11  49.0         42  Monthly     1100.0        14268.0           Spain
# 12  53.0         14  Monthly     3000.0        38916.0     Netherlands
# 14   NaN         13      NaN        NaN            NaN          France
#
#             CURRENCYDESC  ...           SURVEYLENGTH TRANS  \
# 10        Pound sterling  ...  Appropriate in length    No
# 20                   NaN  ...  Appropriate in length    No
# 18  United States dollar  ...  Appropriate in length    No
# 16  United States dollar  ...  Appropriate in length    No
# 13  United States dollar  ...  Appropriate in length    No
# 17  United States dollar  ...  Appropriate in length    No
# 19         European Euro  ...              Too short    No
# 15        Pound sterling  ...  Appropriate in length    No
# 11         European Euro  ...  Appropriate in length    No
# 12         European Euro  ...               Too long    No
# 14                   NaN  ...  Appropriate in length    No
#
#                                        UNDERGRADMAJOR  \
# 10  Computer science, computer engineering, or sof...
# 20                                                NaN
# 18  Computer science, computer engineering, or sof...
# 16  Computer science, computer engineering, or sof...
# 13  Computer science, computer engineering, or sof...
# 17  Computer science, computer engineering, or sof...
# 19  Another engineering discipline (such as civil,...
# 15  Computer science, computer engineering, or sof...
# 11                          Mathematics or statistics
# 12                                                NaN
# 14  Computer science, computer engineering, or sof...
#
#                  WEBFRAMEDESIRENEXTYEAR  \
# 10              Angular;Django;React.js
# 20        Gatsby;React.js;Spring;Vue.js
# 18              Django;Express;React.js
# 16  ASP.NET Core;Gatsby;React.js;Vue.js
# 13                       Angular;Vue.js
# 17                                  NaN
# 19                               Spring
# 15                                  NaN
# 11                       ASP.NET;jQuery
# 12                                  NaN
# 14                                  NaN
#
#                               WEBFRAMEWORKEDWITH  \
# 10            Angular;Angular.js;Django;React.js
# 20  Angular;ASP.NET Core;Express;React.js;Spring
# 18               Angular;Angular.js;ASP.NET Core
# 16         ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 13                                Angular;Vue.js
# 17                                           NaN
# 19                             Angular.js;Spring
# 15                               jQuery;React.js
# 11                                ASP.NET;jQuery
# 12                                           NaN
# 14                                           NaN
#
#                               WELCOMECHANGE WORKWEEKHRS YEARSCODE  \
# 10  Just as welcome now as I felt last year        40.0        10
# 20                                      NaN         NaN         7
# 18  Just as welcome now as I felt last year        35.0         9
# 16  Just as welcome now as I felt last year        40.0         7
# 13  Just as welcome now as I felt last year        40.0         5
# 17  Just as welcome now as I felt last year        45.0        19
# 19  Just as welcome now as I felt last year        50.0        22
# 15  Just as welcome now as I felt last year        50.0        37
# 11  Just as welcome now as I felt last year        40.0         7
# 12    A lot less welcome now than last year        36.0        35
# 14  Just as welcome now as I felt last year         NaN         4
#
#    YEARSCODEPRO (10, HOBBYIST)
# 10            2            Yes
# 20          NaN            Yes
# 18            3            Yes
# 16            3            Yes
# 13            1            Yes
# 17           12            Yes
# 19           17            Yes
# 15           23            Yes
# 11            7            Yes
# 12           20            Yes
# 14          NaN            Yes
#
# [11 rows x 62 columns]

# %%
df['CONVERTEDCOMP'].nlargest(10)
# Out:
# 121     2000000.0
# 123     2000000.0
# 191     2000000.0
# 663     2000000.0
# 697     2000000.0
# 722     2000000.0
# 816     2000000.0
# 982     2000000.0
# 1018    2000000.0
# 1032    2000000.0
# Name: CONVERTEDCOMP, dtype: float64

# %%
df.nlargest(10,'CONVERTEDCOMP')
df.nsmallest(10,'CONVERTEDCOMP')
# Out:
#       RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 122          124                     I am a developer by profession       No
# 236          238  I am not primarily a developer, but I write co...      Yes
# 882          884                     I am a developer by profession      Yes
# 1112        1116                     I am a developer by profession      Yes
# 1272        1278                     I am a developer by profession      Yes
# 1785        1794                     I am a developer by profession      Yes
# 2064        2073                     I am a developer by profession      Yes
# 2187        2196                     I am a developer by profession      Yes
# 2239        2248                     I am a developer by profession       No
# 2314        2323                     I am a developer by profession      Yes
#
#        AGE AGE1STCODE COMPFREQ  COMPTOTAL  CONVERTEDCOMP              COUNTRY  \
# 122   38.0         14   Yearly        0.0            0.0        United States
# 236    NaN         13   Yearly        0.0            0.0        United States
# 882   41.0         10   Yearly        0.0            0.0        United States
# 1112  25.0         11   Yearly        0.0            0.0        United States
# 1272  21.0         12   Yearly        0.0            0.0       United Kingdom
# 1785   NaN          8   Yearly        0.0            0.0        United States
# 2064  27.0         18   Yearly        0.0            0.0               Canada
# 2187   NaN         24  Monthly        1.0            0.0  Republic of Moldova
# 2239   NaN         12   Yearly        0.0            0.0        United States
# 2314   NaN         15   Yearly        0.0            0.0        United States
#
#               CURRENCYDESC  ...           SURVEYLENGTH TRANS  \
# 122   United States dollar  ...              Too short    No
# 236   United States dollar  ...               Too long    No
# 882   United States dollar  ...  Appropriate in length    No
# 1112  United States dollar  ...  Appropriate in length    No
# 1272        Pound sterling  ...  Appropriate in length    No
# 1785  United States dollar  ...  Appropriate in length    No
# 2064       Canadian dollar  ...  Appropriate in length    No
# 2187          Moldovan leu  ...               Too long    No
# 2239  United States dollar  ...  Appropriate in length   NaN
# 2314  United States dollar  ...                    NaN   NaN
#
#                                          UNDERGRADMAJOR  \
# 122   A humanities discipline (such as literature, h...
# 236                                                 NaN
# 882   Computer science, computer engineering, or sof...
# 1112  Computer science, computer engineering, or sof...
# 1272  Computer science, computer engineering, or sof...
# 1785                                                NaN
# 2064  A natural science (such as biology, chemistry,...
# 2187  A social science (such as anthropology, psycho...
# 2239  Computer science, computer engineering, or sof...
# 2314  Computer science, computer engineering, or sof...
#
#      WEBFRAMEDESIRENEXTYEAR                  WEBFRAMEWORKEDWITH  \
# 122                     NaN                                 NaN
# 236         jQuery;React.js                              jQuery
# 882                React.js                            React.js
# 1112               React.js                            React.js
# 1272         Express;Vue.js             Express;jQuery;React.js
# 1785                ASP.NET                             ASP.NET
# 2064        Gatsby;React.js  Angular;Angular.js;Gatsby;React.js
# 2187                 Vue.js                        Flask;Vue.js
# 2239                    NaN                               Flask
# 2314                Angular                  Angular;Angular.js
#
#                                  WELCOMECHANGE WORKWEEKHRS YEARSCODE  \
# 122   Somewhat less welcome now than last year        60.0        24
# 236                                        NaN        12.0         4
# 882    Just as welcome now as I felt last year        50.0        25
# 1112   Just as welcome now as I felt last year        55.0        14
# 1272   Just as welcome now as I felt last year        40.0         9
# 1785                                       NaN        55.0         2
# 2064   Just as welcome now as I felt last year        60.0         5
# 2187   Just as welcome now as I felt last year        60.0         8
# 2239     A lot less welcome now than last year        35.0        12
# 2314   Just as welcome now as I felt last year        45.0        38
#
#      YEARSCODEPRO (10, HOBBYIST)
# 122            19            Yes
# 236             2            Yes
# 882            10            Yes
# 1112            4            Yes
# 1272            2            Yes
# 1785            9            Yes
# 2064            4            Yes
# 2187            3            Yes
# 2239           12            Yes
# 2314           22            Yes
#
# [10 rows x 62 columns]

# %%
import scipy as sp
from scipy.fftpack import fft, ifft
x = np.array([1,2,3,4])
y = fft(x)
z = ifft(y).astype('int')
print(x, z)
# Out:
# [1 2 3 4] [1 2 3 4]
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   """
